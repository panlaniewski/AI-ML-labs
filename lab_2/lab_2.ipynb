# %% [markdown]
# # Лабораторная работа №2
# ## Задачи регрессии и классификации. Линейные модели: линейная и логистическая регрессии

# %%
import pandas as pd

# %%
df = pd.read_csv("../lab_1/data/bigmart_data_processed.csv", index_col=0)
df
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0       -0.841872        -0.970732  1.920266                       1999
# 1       -1.641706        -0.908111 -1.682095                       2009
# 2        1.098554        -0.956917 -0.013563                       1999
# 3        1.500838        -1.281758  0.709930                       1998
# 4       -0.929428        -1.281758 -1.582139                       1987
# ...           ...              ...       ...                        ...
# 8518    -1.418084        -0.181193  1.289532                       1987
# 8519    -1.059578        -0.371154  0.033711                       2002
# 8520    -0.534243        -0.599784 -1.023375                       2004
# 8521    -1.336444         1.532880  0.033711                       2009
# 8522     0.459634        -0.411936 -1.195957                       1997
#
#       Item_Outlet_Sales  Item_Identifier_DRA24  Item_Identifier_DRA59  \
# ...
